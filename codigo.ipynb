# %%
# !pip install PyPDF2
# importa as bibliotecas necessárias
import PyPDF2
import re

# Abre o arquivo pdf 
pdf_file = open("Comite_de_Crise_Covid_19.pdf", 'rb')

#Faz a leitura usando a biblioteca
read_pdf = PyPDF2.PdfReader(pdf_file)

# pega o numero de páginas
#number_of_pages = len(read_pdf.pages)
# Out:
# ...
#      -------------------------------------- 232.6/232.6 kB 6.9 MB/s eta 0:00:00
# ...

# %%
page0 = read_pdf.pages[0]
page1 = read_pdf.pages[1]
page2 = read_pdf.pages[2]
page3 = read_pdf.pages[3]
page4 = read_pdf.pages[4]
page5 = read_pdf.pages[5]
page6 = read_pdf.pages[6]
page7 = read_pdf.pages[7]
page8 = read_pdf.pages[8]
page9 = read_pdf.pages[9]
page10 = read_pdf.pages[10]
page11 = read_pdf.pages[11]
page12 = read_pdf.pages[12]
page13 = read_pdf.pages[13]
page14 = read_pdf.pages[14]
page15 = read_pdf.pages[15]
page16 = read_pdf.pages[16]
page17 = read_pdf.pages[17]
page18 = read_pdf.pages[18]
page19 = read_pdf.pages[19]
page20 = read_pdf.pages[20]
page21 = read_pdf.pages[21]
page22 = read_pdf.pages[22]
page23 = read_pdf.pages[23]
page24 = read_pdf.pages[24]
page25 = read_pdf.pages[25]
page26 = read_pdf.pages[26]
page27 = read_pdf.pages[27]
page28 = read_pdf.pages[28]
page29 = read_pdf.pages[29]
page30 = read_pdf.pages[30]
page31 = read_pdf.pages[31]
page32 = read_pdf.pages[32]
page33 = read_pdf.pages[33]
page34 = read_pdf.pages[34]
page35 = read_pdf.pages[35]
page36 = read_pdf.pages[36]
page37 = read_pdf.pages[37]
page38 = read_pdf.pages[38]
page39 = read_pdf.pages[39]
page40 = read_pdf.pages[40]
page41 = read_pdf.pages[41]
page42 = read_pdf.pages[42]
page43 = read_pdf.pages[43]
page44 = read_pdf.pages[44]
page45 = read_pdf.pages[45]
page46 = read_pdf.pages[46]
page47 = read_pdf.pages[47]
page48 = read_pdf.pages[48]
page49 = read_pdf.pages[49]
page50 = read_pdf.pages[50]
page51 = read_pdf.pages[51]
page52 = read_pdf.pages[52]
page53 = read_pdf.pages[53]
page54 = read_pdf.pages[54]
page55 = read_pdf.pages[55]
page56 = read_pdf.pages[56]
page57 = read_pdf.pages[57]
page58 = read_pdf.pages[58]
page59 = read_pdf.pages[59]
page60 = read_pdf.pages[60]
page61 = read_pdf.pages[61]
page62 = read_pdf.pages[62]
page63 = read_pdf.pages[63]
page64 = read_pdf.pages[64]
page65 = read_pdf.pages[65]
page66 = read_pdf.pages[66]
page67 = read_pdf.pages[67]
page68 = read_pdf.pages[68]
page69 = read_pdf.pages[69]
page70 = read_pdf.pages[70]
page71 = read_pdf.pages[71]
page72 = read_pdf.pages[72]
page73 = read_pdf.pages[73]
page74 = read_pdf.pages[74]
page75 = read_pdf.pages[75]
page76 = read_pdf.pages[76]
page77 = read_pdf.pages[77]
page78 = read_pdf.pages[78]
page79 = read_pdf.pages[79]
page80 = read_pdf.pages[80]
page81 = read_pdf.pages[81]
page82 = read_pdf.pages[82]
page83 = read_pdf.pages[83]
page84 = read_pdf.pages[84]
page85 = read_pdf.pages[85]
page86 = read_pdf.pages[86]
page87 = read_pdf.pages[87]
page88 = read_pdf.pages[88]
page89 = read_pdf.pages[89]
page90 = read_pdf.pages[90]
page91 = read_pdf.pages[91]
page92 = read_pdf.pages[92]
page93 = read_pdf.pages[93]
page94 = read_pdf.pages[94]
page95 = read_pdf.pages[95]
page96 = read_pdf.pages[96]
page97 = read_pdf.pages[97]
page98 = read_pdf.pages[98]
page99 = read_pdf.pages[99]
page100 = read_pdf.pages[100]
page101 = read_pdf.pages[101]
page102 = read_pdf.pages[102]
page103 = read_pdf.pages[103]
page104 = read_pdf.pages[104]
page105 = read_pdf.pages[105]
page106 = read_pdf.pages[106]
page107 = read_pdf.pages[107]
page108 = read_pdf.pages[108]
page109 = read_pdf.pages[109]
page110 = read_pdf.pages[110]
page111 = read_pdf.pages[111]
page112 = read_pdf.pages[112]
page113 = read_pdf.pages[113]
page114 = read_pdf.pages[114]
page115 = read_pdf.pages[115]
page116 = read_pdf.pages[116]
page117 = read_pdf.pages[117]
page118 = read_pdf.pages[118]
page119 = read_pdf.pages[119]
page120 = read_pdf.pages[120]
page121 = read_pdf.pages[121]
page122 = read_pdf.pages[122]
page123 = read_pdf.pages[123]
page124 = read_pdf.pages[124]
page125 = read_pdf.pages[125]
page126 = read_pdf.pages[126]
page127 = read_pdf.pages[127]
page128 = read_pdf.pages[128]
page129 = read_pdf.pages[129]
page130 = read_pdf.pages[130]
page131 = read_pdf.pages[131]
page132 = read_pdf.pages[132]
page133 = read_pdf.pages[133]
page134 = read_pdf.pages[134]
page135 = read_pdf.pages[135]
page136 = read_pdf.pages[136]
page137 = read_pdf.pages[137]
page138 = read_pdf.pages[138]
page139 = read_pdf.pages[139]
page140 = read_pdf.pages[140]
page141 = read_pdf.pages[141]
page142 = read_pdf.pages[142]
page143 = read_pdf.pages[143]
page144 = read_pdf.pages[144]
page145 = read_pdf.pages[145]
page146 = read_pdf.pages[146]
page147 = read_pdf.pages[147]
page148 = read_pdf.pages[148]
page149 = read_pdf.pages[149]
page150 = read_pdf.pages[150]
page151 = read_pdf.pages[151]
page152 = read_pdf.pages[152]
page153 = read_pdf.pages[153]
page154 = read_pdf.pages[154]
page155 = read_pdf.pages[155]
page156 = read_pdf.pages[156]
page157 = read_pdf.pages[157]
page158 = read_pdf.pages[158]
page159 = read_pdf.pages[159]
page160 = read_pdf.pages[160]
page161 = read_pdf.pages[161]
page162 = read_pdf.pages[162]
page163 = read_pdf.pages[163]
page164 = read_pdf.pages[164]
page165 = read_pdf.pages[165]
page166 = read_pdf.pages[166]
page167 = read_pdf.pages[167]
page168 = read_pdf.pages[168]
page169 = read_pdf.pages[169]
page170 = read_pdf.pages[170]
page171 = read_pdf.pages[171]
page172 = read_pdf.pages[172]
page173 = read_pdf.pages[173]
page174 = read_pdf.pages[174]
page175 = read_pdf.pages[175]
page176 = read_pdf.pages[176]
page177 = read_pdf.pages[177]
page178 = read_pdf.pages[178]
page179 = read_pdf.pages[179]
page180 = read_pdf.pages[180]
page181 = read_pdf.pages[181]
page182 = read_pdf.pages[182]
page183 = read_pdf.pages[183]
page184 = read_pdf.pages[184]
page185 = read_pdf.pages[185]
page186 = read_pdf.pages[186]
page187 = read_pdf.pages[187]
page188 = read_pdf.pages[188]
page189 = read_pdf.pages[189]
page190 = read_pdf.pages[190]
page191 = read_pdf.pages[191]
page192 = read_pdf.pages[192]
page193 = read_pdf.pages[193]
page194 = read_pdf.pages[194]
page195 = read_pdf.pages[195]
page196 = read_pdf.pages[196]
page197 = read_pdf.pages[197]
page198 = read_pdf.pages[198]
page199 = read_pdf.pages[199]
page200 = read_pdf.pages[200]
page201 = read_pdf.pages[201]
page202 = read_pdf.pages[202]
page203 = read_pdf.pages[203]
page204 = read_pdf.pages[204]
page205 = read_pdf.pages[205]
page206 = read_pdf.pages[206]
page207 = read_pdf.pages[207]
page208 = read_pdf.pages[208]
page209 = read_pdf.pages[209]
page210 = read_pdf.pages[210]
page211 = read_pdf.pages[211]
page212 = read_pdf.pages[212]
page213 = read_pdf.pages[213]
page214 = read_pdf.pages[214]
page215 = read_pdf.pages[215]
page216 = read_pdf.pages[216]
page217 = read_pdf.pages[217]
page218 = read_pdf.pages[218]
page219 = read_pdf.pages[219]
page220 = read_pdf.pages[220]
page221 = read_pdf.pages[221]
page222 = read_pdf.pages[222]
page223 = read_pdf.pages[223]
page224 = read_pdf.pages[224]
page225 = read_pdf.pages[225]
page226 = read_pdf.pages[226]
page227 = read_pdf.pages[227]
page228 = read_pdf.pages[228]
page229 = read_pdf.pages[229]
page230 = read_pdf.pages[230]
page231 = read_pdf.pages[231]
page232 = read_pdf.pages[232]
page233 = read_pdf.pages[233]
page234 = read_pdf.pages[234]
page235 = read_pdf.pages[235]
page236 = read_pdf.pages[236]
page237 = read_pdf.pages[237]
page238 = read_pdf.pages[238]
page239 = read_pdf.pages[239]
page240 = read_pdf.pages[240]
page241 = read_pdf.pages[241]
page242 = read_pdf.pages[242]
page243 = read_pdf.pages[243]
page244 = read_pdf.pages[244]
page245 = read_pdf.pages[245]
page246 = read_pdf.pages[246]
page247 = read_pdf.pages[247]
page248 = read_pdf.pages[248]
page249 = read_pdf.pages[249]
page250 = read_pdf.pages[250]
page251 = read_pdf.pages[251]
page252 = read_pdf.pages[252]
page253 = read_pdf.pages[253]
page254 = read_pdf.pages[254]
page255 = read_pdf.pages[255]
page256 = read_pdf.pages[256]
page257 = read_pdf.pages[257]
page258 = read_pdf.pages[258]
page259 = read_pdf.pages[259]
page260 = read_pdf.pages[260]
page261 = read_pdf.pages[261]
page262 = read_pdf.pages[262]
page263 = read_pdf.pages[263]
page264 = read_pdf.pages[264]
page265 = read_pdf.pages[265]
page266 = read_pdf.pages[266]
page267 = read_pdf.pages[267]
page268 = read_pdf.pages[268]
page269 = read_pdf.pages[269]
page270 = read_pdf.pages[270]
page271 = read_pdf.pages[271]
page272 = read_pdf.pages[272]
page273 = read_pdf.pages[273]
page274 = read_pdf.pages[274]
page275 = read_pdf.pages[275]
page276 = read_pdf.pages[276]
page277 = read_pdf.pages[277]
page278 = read_pdf.pages[278]
page279 = read_pdf.pages[279]
page280 = read_pdf.pages[280]
page281 = read_pdf.pages[281]
page282 = read_pdf.pages[282]
page283 = read_pdf.pages[283]
page284 = read_pdf.pages[284]
page285 = read_pdf.pages[285]
page286 = read_pdf.pages[286]
page287 = read_pdf.pages[287]
page288 = read_pdf.pages[288]
page289 = read_pdf.pages[289]
page290 = read_pdf.pages[290]
page291 = read_pdf.pages[291]
page292 = read_pdf.pages[292]
page293 = read_pdf.pages[293]
page294 = read_pdf.pages[294]
page295 = read_pdf.pages[295]
page296 = read_pdf.pages[296]
page297 = read_pdf.pages[297]
page298 = read_pdf.pages[298]
page299 = read_pdf.pages[299]
page300 = read_pdf.pages[300]
page301 = read_pdf.pages[301]
page302 = read_pdf.pages[302]
page303 = read_pdf.pages[303]
page304 = read_pdf.pages[304]
page305 = read_pdf.pages[305]
page306 = read_pdf.pages[306]
page307 = read_pdf.pages[307]
page308 = read_pdf.pages[308]
page309 = read_pdf.pages[309]
page310 = read_pdf.pages[310]
page311 = read_pdf.pages[311]
page312 = read_pdf.pages[312]
page313 = read_pdf.pages[313]
page314 = read_pdf.pages[314]
page315 = read_pdf.pages[315]
page316 = read_pdf.pages[316]
page317 = read_pdf.pages[317]
page318 = read_pdf.pages[318]
page319 = read_pdf.pages[319]
page320 = read_pdf.pages[320]
page321 = read_pdf.pages[321]
page322 = read_pdf.pages[322]
page323 = read_pdf.pages[323]
page324 = read_pdf.pages[324]
page325 = read_pdf.pages[325]
page326 = read_pdf.pages[326]
page327 = read_pdf.pages[327]
page328 = read_pdf.pages[328]
page329 = read_pdf.pages[329]
page330 = read_pdf.pages[330]
page331 = read_pdf.pages[331]
page332 = read_pdf.pages[332]
page333 = read_pdf.pages[333]
page334 = read_pdf.pages[334]
page335 = read_pdf.pages[335]
page336 = read_pdf.pages[336]
page337 = read_pdf.pages[337]
page338 = read_pdf.pages[338]
page339 = read_pdf.pages[339]
page340 = read_pdf.pages[340]
page341 = read_pdf.pages[341]
page342 = read_pdf.pages[342]
page343 = read_pdf.pages[343]
page344 = read_pdf.pages[344]
page345 = read_pdf.pages[345]
page346 = read_pdf.pages[346]
page347 = read_pdf.pages[347]
page348 = read_pdf.pages[348]
page349 = read_pdf.pages[349]
page350 = read_pdf.pages[350]
page351 = read_pdf.pages[351]
page352 = read_pdf.pages[352]
page353 = read_pdf.pages[353]
page354 = read_pdf.pages[354]
page355 = read_pdf.pages[355]
page356 = read_pdf.pages[356]
page357 = read_pdf.pages[357]
page358 = read_pdf.pages[358]
page359 = read_pdf.pages[359]
page360 = read_pdf.pages[360]
page361 = read_pdf.pages[361]
page362 = read_pdf.pages[362]
page363 = read_pdf.pages[363]
page364 = read_pdf.pages[364]
page365 = read_pdf.pages[365]
page366 = read_pdf.pages[366]
page367 = read_pdf.pages[367]
page368 = read_pdf.pages[368]
page369 = read_pdf.pages[369]
page370 = read_pdf.pages[370]
page371 = read_pdf.pages[371]
page372 = read_pdf.pages[372]
page373 = read_pdf.pages[373]
page374 = read_pdf.pages[374]
page375 = read_pdf.pages[375]
page376 = read_pdf.pages[376]
page377 = read_pdf.pages[377]
page378 = read_pdf.pages[378]
page379 = read_pdf.pages[379]
page380 = read_pdf.pages[380]
page381 = read_pdf.pages[381]
page382 = read_pdf.pages[382]
page383 = read_pdf.pages[383]
page384 = read_pdf.pages[384]
page385 = read_pdf.pages[385]
page386 = read_pdf.pages[386]
page387 = read_pdf.pages[387]
page388 = read_pdf.pages[388]
page389 = read_pdf.pages[389]
page390 = read_pdf.pages[390]
page391 = read_pdf.pages[391]
page392 = read_pdf.pages[392]
page393 = read_pdf.pages[393]
page394 = read_pdf.pages[394]
page395 = read_pdf.pages[395]
page396 = read_pdf.pages[396]
page397 = read_pdf.pages[397]
page398 = read_pdf.pages[398]
page399 = read_pdf.pages[399]
page400 = read_pdf.pages[400]
page401 = read_pdf.pages[401]
page402 = read_pdf.pages[402]
page403 = read_pdf.pages[403]
page404 = read_pdf.pages[404]
page405 = read_pdf.pages[405]
page406 = read_pdf.pages[406]
page407 = read_pdf.pages[407]
page408 = read_pdf.pages[408]
page409 = read_pdf.pages[409]
page410 = read_pdf.pages[410]
page411 = read_pdf.pages[411]
page412 = read_pdf.pages[412]
page413 = read_pdf.pages[413]
page414 = read_pdf.pages[414]
page415 = read_pdf.pages[415]
page416 = read_pdf.pages[416]
page417 = read_pdf.pages[417]
page418 = read_pdf.pages[418]
page419 = read_pdf.pages[419]
page420 = read_pdf.pages[420]
page421 = read_pdf.pages[421]
page422 = read_pdf.pages[422]
page423 = read_pdf.pages[423]
page424 = read_pdf.pages[424]
page425 = read_pdf.pages[425]
page426 = read_pdf.pages[426]
page427 = read_pdf.pages[427]
page428 = read_pdf.pages[428]
page429 = read_pdf.pages[429]
page430 = read_pdf.pages[430]
page431 = read_pdf.pages[431]
page432 = read_pdf.pages[432]
page433 = read_pdf.pages[433]
page434 = read_pdf.pages[434]
page435 = read_pdf.pages[435]
page436 = read_pdf.pages[436]
page437 = read_pdf.pages[437]
page438 = read_pdf.pages[438]
page439 = read_pdf.pages[439]
page440 = read_pdf.pages[440]
page441 = read_pdf.pages[441]
page442 = read_pdf.pages[442]
page443 = read_pdf.pages[443]
page444 = read_pdf.pages[444]
page445 = read_pdf.pages[445]
page446 = read_pdf.pages[446]
page447 = read_pdf.pages[447]
page448 = read_pdf.pages[448]
page449 = read_pdf.pages[449]
page450 = read_pdf.pages[450]
page451 = read_pdf.pages[451]
page452 = read_pdf.pages[452]
page453 = read_pdf.pages[453]
page454 = read_pdf.pages[454]
page455 = read_pdf.pages[455]
page456 = read_pdf.pages[456]
page457 = read_pdf.pages[457]
page458 = read_pdf.pages[458]
page459 = read_pdf.pages[459]
page460 = read_pdf.pages[460]
page461 = read_pdf.pages[461]
page462 = read_pdf.pages[462]
page463 = read_pdf.pages[463]
page464 = read_pdf.pages[464]
page465 = read_pdf.pages[465]
page466 = read_pdf.pages[466]
page467 = read_pdf.pages[467]
page468 = read_pdf.pages[468]
page469 = read_pdf.pages[469]
page470 = read_pdf.pages[470]
page471 = read_pdf.pages[471]
page472 = read_pdf.pages[472]
page473 = read_pdf.pages[473]
page474 = read_pdf.pages[474]
page475 = read_pdf.pages[475]
page476 = read_pdf.pages[476]
page477 = read_pdf.pages[477]
page478 = read_pdf.pages[478]
page479 = read_pdf.pages[479]
page480 = read_pdf.pages[480]
page481 = read_pdf.pages[481]
page482 = read_pdf.pages[482]
page483 = read_pdf.pages[483]
page484 = read_pdf.pages[484]
page485 = read_pdf.pages[485]
page486 = read_pdf.pages[486]
page487 = read_pdf.pages[487]
page488 = read_pdf.pages[488]
page489 = read_pdf.pages[489]
page490 = read_pdf.pages[490]
page491 = read_pdf.pages[491]
page492 = read_pdf.pages[492]
page493 = read_pdf.pages[493]
page494 = read_pdf.pages[494]
page495 = read_pdf.pages[495]
page496 = read_pdf.pages[496]
page497 = read_pdf.pages[497]
page498 = read_pdf.pages[498]
page499 = read_pdf.pages[499]
page500 = read_pdf.pages[500]
page501 = read_pdf.pages[501]
page502 = read_pdf.pages[502]
page503 = read_pdf.pages[503]
page504 = read_pdf.pages[504]
page505 = read_pdf.pages[505]
page506 = read_pdf.pages[506]
page507 = read_pdf.pages[507]
page508 = read_pdf.pages[508]
page509 = read_pdf.pages[509]
page510 = read_pdf.pages[510]
page511 = read_pdf.pages[511]
page512 = read_pdf.pages[512]
page513 = read_pdf.pages[513]
page514 = read_pdf.pages[514]
page515 = read_pdf.pages[515]
page516 = read_pdf.pages[516]
page517 = read_pdf.pages[517]
page518 = read_pdf.pages[518]
page519 = read_pdf.pages[519]
page520 = read_pdf.pages[520]
page521 = read_pdf.pages[521]
page522 = read_pdf.pages[522]
page523 = read_pdf.pages[523]
page524 = read_pdf.pages[524]
page525 = read_pdf.pages[525]
page526 = read_pdf.pages[526]
page527 = read_pdf.pages[527]
page528 = read_pdf.pages[528]
page529 = read_pdf.pages[529]
page530 = read_pdf.pages[530]
page531 = read_pdf.pages[531]
page532 = read_pdf.pages[532]
page533 = read_pdf.pages[533]
page534 = read_pdf.pages[534]
page535 = read_pdf.pages[535]
page536 = read_pdf.pages[536]
page537 = read_pdf.pages[537]
page538 = read_pdf.pages[538]
page539 = read_pdf.pages[539]
page540 = read_pdf.pages[540]
page541 = read_pdf.pages[541]
page542 = read_pdf.pages[542]
page543 = read_pdf.pages[543]
page544 = read_pdf.pages[544]
page545 = read_pdf.pages[545]
page546 = read_pdf.pages[546]
page547 = read_pdf.pages[547]
page548 = read_pdf.pages[548]
page549 = read_pdf.pages[549]
page550 = read_pdf.pages[550]
page551 = read_pdf.pages[551]
page552 = read_pdf.pages[552]
page553 = read_pdf.pages[553]
page554 = read_pdf.pages[554]
page555 = read_pdf.pages[555]
page556 = read_pdf.pages[556]
page557 = read_pdf.pages[557]
page558 = read_pdf.pages[558]
page559 = read_pdf.pages[559]
page560 = read_pdf.pages[560]
page561 = read_pdf.pages[561]
page562 = read_pdf.pages[562]
page563 = read_pdf.pages[563]
page564 = read_pdf.pages[564]
page565 = read_pdf.pages[565]
page566 = read_pdf.pages[566]
page567 = read_pdf.pages[567]
page568 = read_pdf.pages[568]
page569 = read_pdf.pages[569]
page570 = read_pdf.pages[570]
page571 = read_pdf.pages[571]
page572 = read_pdf.pages[572]
page573 = read_pdf.pages[573]
page574 = read_pdf.pages[574]
page575 = read_pdf.pages[575]
page576 = read_pdf.pages[576]
page577 = read_pdf.pages[577]
page578 = read_pdf.pages[578]
page579 = read_pdf.pages[579]
page580 = read_pdf.pages[580]
page581 = read_pdf.pages[581]
page582 = read_pdf.pages[582]
page583 = read_pdf.pages[583]
page584 = read_pdf.pages[584]
page585 = read_pdf.pages[585]
page586 = read_pdf.pages[586]
page587 = read_pdf.pages[587]
page588 = read_pdf.pages[588]
page589 = read_pdf.pages[589]
page590 = read_pdf.pages[590]
page591 = read_pdf.pages[591]
page592 = read_pdf.pages[592]
page593 = read_pdf.pages[593]
page594 = read_pdf.pages[594]
page595 = read_pdf.pages[595]
page596 = read_pdf.pages[596]
page597 = read_pdf.pages[597]
page598 = read_pdf.pages[598]
page599 = read_pdf.pages[599]
page600 = read_pdf.pages[600]
page601 = read_pdf.pages[601]
page602 = read_pdf.pages[602]
page603 = read_pdf.pages[603]
page604 = read_pdf.pages[604]
page605 = read_pdf.pages[605]
page606 = read_pdf.pages[606]
page607 = read_pdf.pages[607]
page608 = read_pdf.pages[608]
page609 = read_pdf.pages[609]
page610 = read_pdf.pages[610]
page611 = read_pdf.pages[611]
page612 = read_pdf.pages[612]
page613 = read_pdf.pages[613]
page614 = read_pdf.pages[614]
page615 = read_pdf.pages[615]
page616 = read_pdf.pages[616]
page617 = read_pdf.pages[617]
page618 = read_pdf.pages[618]
page619 = read_pdf.pages[619]
page620 = read_pdf.pages[620]
page621 = read_pdf.pages[621]
page622 = read_pdf.pages[622]
page623 = read_pdf.pages[623]
page624 = read_pdf.pages[624]
page625 = read_pdf.pages[625]
page626 = read_pdf.pages[626]
page627 = read_pdf.pages[627]
page628 = read_pdf.pages[628]
page629 = read_pdf.pages[629]
page630 = read_pdf.pages[630]
page631 = read_pdf.pages[631]
page632 = read_pdf.pages[632]
page633 = read_pdf.pages[633]
page634 = read_pdf.pages[634]
page635 = read_pdf.pages[635]
page636 = read_pdf.pages[636]
page637 = read_pdf.pages[637]
page638 = read_pdf.pages[638]
page639 = read_pdf.pages[639]
page640 = read_pdf.pages[640]
page641 = read_pdf.pages[641]
page642 = read_pdf.pages[642]
page643 = read_pdf.pages[643]
page644 = read_pdf.pages[644]
page645 = read_pdf.pages[645]
page646 = read_pdf.pages[646]
page647 = read_pdf.pages[647]
page648 = read_pdf.pages[648]
page649 = read_pdf.pages[649]
page650 = read_pdf.pages[650]
page651 = read_pdf.pages[651]
page652 = read_pdf.pages[652]
page653 = read_pdf.pages[653]
page654 = read_pdf.pages[654]
page655 = read_pdf.pages[655]
page656 = read_pdf.pages[656]
page657 = read_pdf.pages[657]
page658 = read_pdf.pages[658]
page659 = read_pdf.pages[659]
page660 = read_pdf.pages[660]
page661 = read_pdf.pages[661]
page662 = read_pdf.pages[662]
page663 = read_pdf.pages[663]
page664 = read_pdf.pages[664]
page665 = read_pdf.pages[665]
page666 = read_pdf.pages[666]
page667 = read_pdf.pages[667]
page668 = read_pdf.pages[668]
page669 = read_pdf.pages[669]
page670 = read_pdf.pages[670]
page671 = read_pdf.pages[671]
page672 = read_pdf.pages[672]
page673 = read_pdf.pages[673]
page674 = read_pdf.pages[674]
page675 = read_pdf.pages[675]
page676 = read_pdf.pages[676]
page677 = read_pdf.pages[677]
page678 = read_pdf.pages[678]
page679 = read_pdf.pages[679]
page680 = read_pdf.pages[680]
page681 = read_pdf.pages[681]
page682 = read_pdf.pages[682]
page683 = read_pdf.pages[683]
page684 = read_pdf.pages[684]
page685 = read_pdf.pages[685]
page686 = read_pdf.pages[686]
page687 = read_pdf.pages[687]
page688 = read_pdf.pages[688]
page689 = read_pdf.pages[689]
page690 = read_pdf.pages[690]
page691 = read_pdf.pages[691]
page692 = read_pdf.pages[692]
page693 = read_pdf.pages[693]
page694 = read_pdf.pages[694]
page695 = read_pdf.pages[695]
page696 = read_pdf.pages[696]
page697 = read_pdf.pages[697]
page698 = read_pdf.pages[698]
page699 = read_pdf.pages[699]
page700 = read_pdf.pages[700]
page701 = read_pdf.pages[701]
page702 = read_pdf.pages[702]
page703 = read_pdf.pages[703]
page704 = read_pdf.pages[704]
page705 = read_pdf.pages[705]
page706 = read_pdf.pages[706]
page707 = read_pdf.pages[707]
page708 = read_pdf.pages[708]
page709 = read_pdf.pages[709]
page710 = read_pdf.pages[710]
page711 = read_pdf.pages[711]
page712 = read_pdf.pages[712]
page713 = read_pdf.pages[713]
page714 = read_pdf.pages[714]
page715 = read_pdf.pages[715]
page716 = read_pdf.pages[716]
page717 = read_pdf.pages[717]
page718 = read_pdf.pages[718]
page719 = read_pdf.pages[719]
page720 = read_pdf.pages[720]
page721 = read_pdf.pages[721]
page722 = read_pdf.pages[722]
page723 = read_pdf.pages[723]
page724 = read_pdf.pages[724]
page725 = read_pdf.pages[725]
page726 = read_pdf.pages[726]
page727 = read_pdf.pages[727]
page728 = read_pdf.pages[728]
page729 = read_pdf.pages[729]
page730 = read_pdf.pages[730]
page731 = read_pdf.pages[731]
page732 = read_pdf.pages[732]
page733 = read_pdf.pages[733]
page734 = read_pdf.pages[734]
page735 = read_pdf.pages[735]
page736 = read_pdf.pages[736]
page737 = read_pdf.pages[737]
page738 = read_pdf.pages[738]
page739 = read_pdf.pages[739]
page740 = read_pdf.pages[740]
page741 = read_pdf.pages[741]
page742 = read_pdf.pages[742]
page743 = read_pdf.pages[743]
page744 = read_pdf.pages[744]
page745 = read_pdf.pages[745]
page746 = read_pdf.pages[746]
page747 = read_pdf.pages[747]
page748 = read_pdf.pages[748]
page749 = read_pdf.pages[749]
page750 = read_pdf.pages[750]
page751 = read_pdf.pages[751]
page752 = read_pdf.pages[752]
page753 = read_pdf.pages[753]
page754 = read_pdf.pages[754]
page755 = read_pdf.pages[755]
page756 = read_pdf.pages[756]
page757 = read_pdf.pages[757]
page758 = read_pdf.pages[758]
page759 = read_pdf.pages[759]
page760 = read_pdf.pages[760]
page761 = read_pdf.pages[761]
page762 = read_pdf.pages[762]
page763 = read_pdf.pages[763]
page764 = read_pdf.pages[764]
page765 = read_pdf.pages[765]
page766 = read_pdf.pages[766]
page767 = read_pdf.pages[767]
page768 = read_pdf.pages[768]
page769 = read_pdf.pages[769]
page770 = read_pdf.pages[770]
page771 = read_pdf.pages[771]
page772 = read_pdf.pages[772]
page773 = read_pdf.pages[773]
page774 = read_pdf.pages[774]
page775 = read_pdf.pages[775]
page776 = read_pdf.pages[776]
page777 = read_pdf.pages[777]
page778 = read_pdf.pages[778]
page779 = read_pdf.pages[779]
page780 = read_pdf.pages[780]
page781 = read_pdf.pages[781]
page782 = read_pdf.pages[782]
page783 = read_pdf.pages[783]
page784 = read_pdf.pages[784]
page785 = read_pdf.pages[785]
page786 = read_pdf.pages[786]
page787 = read_pdf.pages[787]
page788 = read_pdf.pages[788]
page789 = read_pdf.pages[789]
page790 = read_pdf.pages[790]
page791 = read_pdf.pages[791]
page792 = read_pdf.pages[792]
page793 = read_pdf.pages[793]
page794 = read_pdf.pages[794]
page795 = read_pdf.pages[795]
page796 = read_pdf.pages[796]
page797 = read_pdf.pages[797]
page798 = read_pdf.pages[798]
page799 = read_pdf.pages[799]
page800 = read_pdf.pages[800]
page801 = read_pdf.pages[801]
page802 = read_pdf.pages[802]
page803 = read_pdf.pages[803]
page804 = read_pdf.pages[804]
page805 = read_pdf.pages[805]

# %%
pages1 = [page0, page1, page2, page3, page4, page5, page6, page7, page8, page9, page10, page11, page12, page13, page14, page15, page16, page17, page18, page19, page20, page21, page22, page23, page24, page25, page26, page27, page28, page29, page30, page31, page32, page33, page34, page35, page36, page37, page38, page39, page40, page41, page42, page43, page44, page45, page46, page47, page48, page49, page50, page51, page52, page53, page54, page55, page56, page57, page58, page59, page60, page61, page62, page63, page64, page65, page66, page67, page68, page69, page70, page71, page72, page73, page74, page75, page76, page77, page78, page79, page80, page81, page82, page83, page84, page85, page86, page87, page88, page89, page90, page91, page92, page93, page94, page95, page96, page97, page98, page99, page100, page101, page102, page103, page104, page105, page106, page107, page108, page109, page110, page111, page112, page113, page114, page115, page116, page117, page118, page119, page120, page121, page122, page123, page124, page125, page126, page127, page128, page129, page130, page131, page132, page133, page134, page135, page136, page137, page138, page139, page140, page141, page142, page143, page144, page145, page146, page147, page148, page149, page150, page151, page152, page153, page154, page155, page156, page157, page158, page159, page160, page161, page162, page163, page164, page165, page166, page167, page168, page169, page170, page171, page172, page173, page174, page175, page176, page177, page178, page179, page180, page181, page182, page183, page184, page185, page186, page187, page188, page189, page190, page191, page192, page193, page194, page195, page196, page197, page198, page199, page200, page201, page202, page203, page204, page205, page206, page207, page208, page209, page210, page211, page212, page213, page214, page215, page216, page217, page218, page219, page220, page221, page222, page223, page224, page225, page226, page227, page228, page229, page230, page231, page232, page233, page234, page235, page236, page237, page238, page239, page240, page241, page242, page243, page244, page245, page246, page247, page248, page249, page250, page251, page252, page253, page254, page255, page256, page257, page258, page259, page260, page261, page262, page263, page264, page265, page266, page267, page268, page269, page270, page271, page272, page273, page274, page275, page276, page277, page278, page279, page280, page281, page282, page283, page284, page285, page286, page287, page288, page289, page290, page291, page292, page293, page294, page295, page296, page297, page298, page299, page300, page301, page302, page303, page304, page305, page306, page307, page308, page309, page310, page311, page312, page313, page314, page315, page316, page317, page318, page319, page320, page321, page322, page323, page324, page325, page326, page327, page328, page329, page330, page331, page332, page333, page334, page335, page336, page337, page338, page339, page340, page341, page342, page343, page344, page345, page346, page347, page348, page349, page350, page351, page352, page353, page354, page355, page356, page357, page358, page359, page360, page361, page362, page363, page364, page365, page366, page367, page368, page369, page370, page371, page372, page373, page374, page375, page376, page377, page378, page379, page380, page381, page382, page383, page384, page385, page386, page387, page388, page389, page390, page391, page392, page393, page394, page395, page396, page397, page398, page399, page400, page401, page402, page403, page404, page405, page406, page407, page408, page409, page410, page411, page412, page413, page414, page415, page416, page417, page418]
pages2 = [page419, page420, page421, page422, page423, page424, page425, page426, page427, page428, page429, page430, page431, page432, page433, page434, page435, page436, page437, page438, page439, page440, page441, page442, page443, page444, page445, page446, page447, page448, page449, page450, page451, page452, page453, page454, page455, page456, page457, page458, page459, page460, page461, page462, page463, page464, page465, page466, page467, page468, page469, page470, page471, page472, page473, page474, page475, page476, page477, page478, page479, page480, page481, page482, page483, page484, page485, page486, page487, page488, page489, page490, page491, page492, page493, page494, page495, page496, page497, page498, page499, page500, page501, page502, page503, page504, page505, page506, page507, page508, page509, page510, page511, page512, page513, page514, page515, page516, page517, page518, page519, page520, page521, page522, page523, page524, page525, page526, page527, page528, page529, page530, page531, page532, page533, page534, page535, page536, page537, page538, page539, page540, page541, page542, page543, page544, page545, page546, page547, page548, page549, page550, page551, page552, page553, page554, page555, page556, page557, page558, page559, page560, page561, page562, page563, page564, page565, page566, page567, page568, page569, page570, page571, page572, page573, page574, page575, page576, page577, page578, page579, page580, page581, page582, page583, page584, page585, page586, page587, page588, page589, page590, page591, page592, page593, page594, page595, page596, page597, page598, page599, page600, page601, page602, page603, page604, page605, page606, page607, page608, page609, page610, page611, page612, page613, page614, page615, page616, page617, page618, page619, page620, page621, page622, page623, page624, page625, page626, page627, page628, page629, page630, page631, page632, page633, page634, page635, page636, page637, page638, page639, page640, page641, page642, page643, page644, page645, page646, page647, page648, page649, page650, page651, page652, page653, page654, page655, page656, page657, page658, page659, page660, page661, page662, page663, page664, page665, page666, page667, page668, page669, page670, page671, page672, page673, page674, page675, page676, page677, page678, page679, page680, page681, page682, page683, page684, page685, page686, page687, page688, page689, page690, page691, page692, page693, page694, page695, page696, page697, page698, page699, page700, page701, page702, page703, page704, page705, page706, page707, page708, page709, page710, page711, page712, page713, page714, page715, page716, page717, page718, page719, page720, page721, page722, page723, page724, page725, page726, page727, page728, page729, page730, page731, page732, page733, page734, page735, page736, page737, page738, page739, page740, page741, page742, page743, page744, page745, page746, page747, page748, page749, page750, page751, page752, page753, page754, page755, page756, page757, page758, page759, page760, page761, page762, page763, page764, page765, page766, page767, page768, page769, page770, page771, page772, page773, page774, page775, page776, page777, page778, page779, page780, page781, page782, page783, page784, page785, page786, page787, page788, page789, page790, page791, page792, page793, page794, page795, page796, page797, page798, page799, page800, page801, page802, page803, page804, page805]

# %%
pages = [page0, page1, page2, page3, page4, page5, page6, page7, page8, page9, page10, page11, page12, page13, page14, page15, page16, page17, page18, page19, page20, page21, page22, page23, page24, page25, page26, page27, page28, page29, page30, page31, page32, page33, page34, page35, page36, page37, page38, page39, page40, page41, page42, page43, page44, page45, page46, page47, page48, page49, page50, page51, page52, page53, page54, page55, page56, page57, page58, page59, page60, page61, page62, page63, page64, page65, page66, page67, page68, page69, page70, page71, page72, page73, page74, page75, page76, page77, page78, page79, page80, page81, page82, page83, page84, page85, page86, page87, page88, page89, page90, page91, page92, page93, page94, page95, page96, page97, page98, page99, page100, page101, page102, page103, page104, page105, page106, page107, page108, page109, page110, page111, page112, page113, page114, page115, page116, page117, page118, page119, page120, page121, page122, page123, page124, page125, page126, page127, page128, page129, page130, page131, page132, page133, page134, page135, page136, page137, page138, page139, page140, page141, page142, page143, page144, page145, page146, page147, page148, page149, page150, page151, page152, page153, page154, page155, page156, page157, page158, page159, page160, page161, page162, page163, page164, page165, page166, page167, page168, page169, page170, page171, page172, page173, page174, page175, page176, page177, page178, page179, page180, page181, page182, page183, page184, page185, page186, page187, page188, page189, page190, page191, page192, page193, page194, page195, page196, page197, page198, page199, page200, page201, page202, page203, page204, page205, page206, page207, page208, page209, page210, page211, page212, page213, page214, page215, page216, page217, page218, page219, page220, page221, page222, page223, page224, page225, page226, page227, page228, page229, page230, page231, page232, page233, page234, page235, page236, page237, page238, page239, page240, page241, page242, page243, page244, page245, page246, page247, page248, page249, page250, page251, page252, page253, page254, page255, page256, page257, page258, page259, page260, page261, page262, page263, page264, page265, page266, page267, page268, page269, page270, page271, page272, page273, page274, page275, page276, page277, page278, page279, page280, page281, page282, page283, page284, page285, page286, page287, page288, page289, page290, page291, page292, page293, page294, page295, page296, page297, page298, page299, page300, page301, page302, page303, page304, page305, page306, page307, page308, page309, page310, page311, page312, page313, page314, page315, page316, page317, page318, page319, page320, page321, page322, page323, page324, page325, page326, page327, page328, page329, page330, page331, page332, page333, page334, page335, page336, page337, page338, page339, page340, page341, page342, page343, page344, page345, page346, page347, page348, page349, page350, page351, page352, page353, page354, page355, page356, page357, page358, page359, page360, page361, page362, page363, page364, page365, page366, page367, page368, page369, page370, page371, page372, page373, page374, page375, page376, page377, page378, page379, page380, page381, page382, page383, page384, page385, page386, page387, page388, page389, page390, page391, page392, page393, page394, page395, page396, page397, page398, page399, page400, page401, page402, page403, page404, page405, page406, page407, page408, page409, page410, page411, page412, page413, page414, page415, page416, page417, page418, page419, page420, page421, page422, page423, page424, page425, page426, page427, page428, page429, page430, page431, page432, page433, page434, page435, page436, page437, page438, page439, page440, page441, page442, page443, page444, page445, page446, page447, page448, page449, page450, page451, page452, page453, page454, page455, page456, page457, page458, page459, page460, page461, page462, page463, page464, page465, page466, page467, page468, page469, page470, page471, page472, page473, page474, page475, page476, page477, page478, page479, page480, page481, page482, page483, page484, page485, page486, page487, page488, page489, page490, page491, page492, page493, page494, page495, page496, page497, page498, page499, page500, page501, page502, page503, page504, page505, page506, page507, page508, page509, page510, page511, page512, page513, page514, page515, page516, page517, page518, page519, page520, page521, page522, page523, page524, page525, page526, page527, page528, page529, page530, page531, page532, page533, page534, page535, page536, page537, page538, page539, page540, page541, page542, page543, page544, page545, page546, page547, page548, page549, page550, page551, page552, page553, page554, page555, page556, page557, page558, page559, page560, page561, page562, page563, page564, page565, page566, page567, page568, page569, page570, page571, page572, page573, page574, page575, page576, page577, page578, page579, page580, page581, page582, page583, page584, page585, page586, page587, page588, page589, page590, page591, page592, page593, page594, page595, page596, page597, page598, page599, page600, page601, page602, page603, page604, page605, page606, page607, page608, page609, page610, page611, page612, page613, page614, page615, page616, page617, page618, page619, page620, page621, page622, page623, page624, page625, page626, page627, page628, page629, page630, page631, page632, page633, page634, page635, page636, page637, page638, page639, page640, page641, page642, page643, page644, page645, page646, page647, page648, page649, page650, page651, page652, page653, page654, page655, page656, page657, page658, page659, page660, page661, page662, page663, page664, page665, page666, page667, page668, page669, page670, page671, page672, page673, page674, page675, page676, page677, page678, page679, page680, page681, page682, page683, page684, page685, page686, page687, page688, page689, page690, page691, page692, page693, page694, page695, page696, page697, page698, page699, page700, page701, page702, page703, page704, page705, page706, page707, page708, page709, page710, page711, page712, page713, page714, page715, page716, page717, page718, page719, page720, page721, page722, page723, page724, page725, page726, page727, page728, page729, page730, page731, page732, page733, page734, page735, page736, page737, page738, page739, page740, page741, page742, page743, page744, page745, page746, page747, page748, page749, page750, page751, page752, page753, page754, page755, page756, page757, page758, page759, page760, page761, page762, page763, page764, page765, page766, page767, page768, page769, page770, page771, page772, page773, page774, page775, page776, page777, page778, page779, page780, page781, page782, page783, page784, page785, page786, page787, page788, page789, page790, page791, page792, page793, page794, page795, page796, page797, page798, page799, page800, page801, page802, page803, page804, page805]

# %%
with open("teste1.txt", 'w', encoding='utf-8')  as arquivo:
    for page in pages1:
        page_content = page.extract_text()
        parsed = ''.join(page_content)
        #parsed = parsed.upper()
        parsed = re.sub("\n", "", parsed)
        parsed = re.sub("\uf0b7", "", parsed)
        parsed = re.sub("  ", " ", parsed)
        parsed = re.sub("Encaminhamentos", "\n\nENCAMINHAMENTOS:\n", parsed)
        parsed = re.sub('Data:', '\n\nDATA:\n', parsed)
        parsed = re.sub(' Memória', "\n\nMEMÓRIA\n", parsed)
        #parsed = re.sub('GABINETE DE SEGURANÇA INSTITUCIONAL', "\n\nGSI", parsed)
        #parsed = re.sub('CASA CIVIL DA PRESIDÊNCIA DA REPÚBLICA  ', "", parsed)
        #parsed = re.sub('\n', ' ', parsed)
        #print(parsed, file=arquivo)
        print(parsed)
# Out:
# CASA CIVIL DA
# PRESIDÊNCIA DA REPÚBLICA 1ª Reunião Ordinária do
# Comitê de Crise para Supervisão e Monitoramento dos Impactos da Covid -19
#
# DATA:
#  17 de março de 2020.
# Horário: 10:00 às 11:00 h.
# Local: Palácio do Planalto , Sala 9 7
# Participante: Conforme lista de presença
# Pauta: Supervisão e monitoramento das ações de enfrentamento à Covid -19
#
# MEMÓRIA
#  Casa Civil da Presidência da República (CC/PR) Informes:
# O objetivo deste Gabinete de Crise é centralizar as informações nesta Casa Civil para que
# não haja informações distorcidas entre os ministérios.
#  Pontos que merecem atenção especial:
# a)  Hospitais de campanha (mapeamento de todos);
# b)  Hospitais de campanha mil itares;
# c)  Presídios – no tocante à prevenção e reações contra possíveis rebeliões (caso existam).
# O Ministro Braga Netto ponderou a todos, que mantenham a calma e não transmitam
# informações erradas e precipitadas para não causar pânico na população, o único meio de
# ...

# %%
with open("teste1.txt", 'w', encoding='utf-8')  as arquivo:
    for page in pages:
        page_content = page.extract_text()
        parsed = ''.join(page_content)
        #parsed = parsed.upper()
        parsed = re.sub("\n \n", "", parsed)
        parsed = re.sub("\uf0b7", "", parsed)
        parsed = re.sub("  ", " ", parsed)
        parsed = re.sub('Memória ', ' ', parsed)
        #parsed = re.sub('GABINETE DE SEGURANÇA INSTITUCIONAL', "\n\nGSI", parsed)
        parsed = re.sub('\n', ' ', parsed)
        parsed = re.sub("Encaminhamentos", "\n\nENCAMINHAMENTOS:\n", parsed)
        parsed = re.sub('Data:', '\n\nDATA:\n', parsed)
        parsed = re.sub(' Memória', "\n\nMEMÓRIA\n", parsed)
        parsed = re.sub('CASA CIVIL DA ', "", parsed)
        #print(parsed, file=arquivo)
        print(parsed)

# %%
with open("teste.txt", 'w', encoding='utf-8')  as arquivo:
    for i in doe_18:
        texto = parser.from_file(i)
        texto = texto['content']
        texto = re.sub("\n", " ", texto)
        texto = re.sub("PORTARIA", "\nPORTARIA ", texto)
        texto = texto.upper()
        print(texto, file=arquivo)
